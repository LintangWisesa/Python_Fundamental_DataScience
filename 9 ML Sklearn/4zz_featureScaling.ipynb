# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %%
data = [169.6,166.8,157.1,181.1,158.4,165.6,166.7,156.5,168.1,165.3]
df = pd.DataFrame(data, columns=['TB'])
df
# Out:
#       TB
# 0  169.6
# 1  166.8
# 2  157.1
# 3  181.1
# 4  158.4
# 5  165.6
# 6  166.7
# 7  156.5
# 8  168.1
# 9  165.3

# %%
print('Unscaled data', df['TB'])
print('Data after standard scaling', StandardScaler().fit_transform(df[['TB']]))
print('Data after min-max scaling', MinMaxScaler().fit_transform(df[['TB']]))
print('Data after max-abs scaling', MaxAbsScaler().fit_transform(df[['TB']]))
print('Data after robust scaling', RobustScaler(quantile_range=(25, 75)).fit_transform(df[['TB']]))
# print('Data after power transformation (Yeo-Johnson)', PowerTransformer(method='yeo-johnson').fit_transform(df[['TB']]))
# print('Data after power transformation (Box-Cox)', PowerTransformer(method='box-cox').fit_transform(df[['TB']]))
print('Data after quantile transformation (gaussian pdf)', QuantileTransformer(output_distribution='normal').fit_transform(df[['TB']]))
print('Data after quantile transformation (uniform pdf)', QuantileTransformer(output_distribution='uniform').fit_transform(df[['TB']]))
print('Data after sample-wise L2 normalizing', Normalizer().fit_transform(df[['TB']]))
# Out:
# Unscaled data 0    169.6
# 1    166.8
# 2    157.1
# 3    181.1
# 4    158.4
# 5    165.6
# 6    166.7
# 7    156.5
# 8    168.1
# 9    165.3
# Name: TB, dtype: float64
# Data after standard scaling [[ 0.59381915]
#  [ 0.18629621]
#  [-1.22547973]
#  [ 2.26757412]
#  [-1.03627264]
#  [ 0.01164351]
#  [ 0.17174181]
#  [-1.31280607]
#  [ 0.37550329]
#  [-0.03201966]]
# Data after min-max scaling [[0.53252033]
#  [0.41869919]
#  [0.02439024]
#  [1.        ]
#  [0.07723577]
#  [0.3699187 ]
#  [0.41463415]
#  [0.        ]
#  [0.47154472]
#  [0.35772358]]
# Data after max-abs scaling [[0.93649917]
#  [0.9210381 ]
#  [0.86747653]
#  [1.        ]
#  [0.87465489]
#  [0.91441193]
#  [0.92048592]
#  [0.86416345]
#  [0.92821645]
#  [0.91275538]]
# Data after robust scaling [[ 0.45098039]
#  [ 0.08496732]
#  [-1.18300654]
#  [ 1.95424837]
#  [-1.0130719 ]
#  [-0.07189542]
#  [ 0.07189542]
#  [-1.26143791]
#  [ 0.25490196]
#  [-0.11111111]]
# ...

# %%
df['Standar'] = StandardScaler().fit_transform(df[['TB']]).reshape(10,)
df['MinMax'] = MinMaxScaler().fit_transform(df[['TB']]).reshape(10,)
df['MaxAbs'] = MaxAbsScaler().fit_transform(df[['TB']]).reshape(10,)
df['Robust'] = RobustScaler(quantile_range=(25, 75)).fit_transform(df[['TB']]).reshape(10,)
# df['Yeo-Johnson'] = PowerTransformer(method='yeo-johnson').fit_transform(df[['TB']]).reshape(10,)
# df['Box-Cox'] = PowerTransformer(method='box-cox').fit_transform(df[['TB']]).reshape(10,)
df['Gaussian pdf'] = QuantileTransformer(output_distribution='normal').fit_transform(df[['TB']]).reshape(10,)
df['Uniform pdf'] = QuantileTransformer(output_distribution='uniform').fit_transform(df[['TB']]).reshape(10,)
df['Normalize'] = Normalizer().fit_transform(df[['TB']]).reshape(10,)
df
# Out:
#       TB   Standar    MinMax    MaxAbs    Robust  Gaussian pdf   Uniform pdf  \
# 0  169.6  0.593819  0.532520  0.936499  0.450980      1.220640  8.888889e-01
# 1  166.8  0.186296  0.418699  0.921038  0.084967      0.430727  6.666667e-01
# 2  157.1 -1.225480  0.024390  0.867477 -1.183007     -1.220640  1.111111e-01
# 3  181.1  2.267574  1.000000  1.000000  1.954248      5.199338  9.999999e-01
# 4  158.4 -1.036273  0.077236  0.874655 -1.013072     -0.764710  2.222222e-01
# 5  165.6  0.011644  0.369919  0.914412 -0.071895     -0.139710  4.444444e-01
# 6  166.7  0.171742  0.414634  0.920486  0.071895      0.139710  5.555556e-01
# 7  156.5 -1.312806  0.000000  0.864163 -1.261438     -5.199338  1.000000e-07
# 8  168.1  0.375503  0.471545  0.928216  0.254902      0.764710  7.777778e-01
# 9  165.3 -0.032020  0.357724  0.912755 -0.111111     -0.430727  3.333333e-01
#
#    Normalize
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# 5        1.0
# 6        1.0
# ...

# %%
sb.pairplot(df)

# %%
scaler = StandardScaler()
scaler.fit(df[['TB']])
scaler.transform(df[['TB']])
# Out:
# array([[ 0.59381915],
#        [ 0.18629621],
#        [-1.22547973],
#        [ 2.26757412],
#        [-1.03627264],
#        [ 0.01164351],
#        [ 0.17174181],
#        [-1.31280607],
#        [ 0.37550329],
#        [-0.03201966]])
