# %% [markdown]
# # Anime Recommendation
#
# ### __2. Collaborative filtering__
#
# Dataset: (https://www.kaggle.com/CooperUnion/anime-recommendations-database)[https://www.kaggle.com/CooperUnion/anime-recommendations-database]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('rating.csv')
df = df.iloc[:5000]
df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
dfNew = df.pivot_table(index='user_id', 
                    columns='anime_id', aggfunc='mean')
dfNew.head()
# Out:
#          rating                                                        ...   \
# anime_id  1     5     6     15    17    18    19    20    22    24     ...
# user_id                                                                ...
# 1           NaN   NaN   NaN   NaN   NaN   NaN   NaN  -1.0   NaN  -1.0  ...
# 2           NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3           NaN   NaN   NaN   NaN   NaN   NaN   NaN   8.0   NaN   NaN  ...
# 4           NaN   NaN  -1.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5           NaN   NaN   8.0   6.0   6.0   6.0   NaN   6.0   5.0   1.0  ...
#
#
# anime_id 33028 33091 33142 33341 33421 33522 33524 33569 33934 34240
# user_id
# 1          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
dfCor = dfNew.corr()
dfCor = dfCor.loc['rating']
# dfCor.loc[1]

# %%
# index, rating
MrA = [(1, 5), (5, 5), (6, 6)]

# %%
skorSama = pd.DataFrame()
for index, rating in MrA:
    skor = dfCor.iloc[rating]
    skor = skor.sort_values(ascending=False)
    skorSama = skorSama.append(skor, ignore_index=True)
    # print(skor)
# skorSama

# %%
skorSama.sum().sort_values(ascending=False)
# Out:
# (rating, 1210)     3.000000
# (rating, 9253)     3.000000
# (rating, 8074)     3.000000
# (rating, 205)      2.994850
# (rating, 1535)     2.967868
# (rating, 19815)    2.000000
# (rating, 18)       2.000000
# (rating, 185)      2.000000
# (rating, 186)      2.000000
# (rating, 7817)     2.000000
# (rating, 13663)    2.000000
# (rating, 15059)    2.000000
# (rating, 14345)    1.000000
# (rating, 801)      1.000000
# (rating, 26055)    1.000000
# (rating, 6811)     1.000000
# (rating, 6746)     1.000000
# (rating, 6707)     1.000000
# (rating, 14131)    1.000000
# (rating, 19315)    1.000000
# (rating, 877)      1.000000
# (rating, 15037)    1.000000
# (rating, 14349)    1.000000
# (rating, 14353)    1.000000
# (rating, 6547)     1.000000
# (rating, 934)      1.000000
# (rating, 6347)     1.000000
# (rating, 777)      1.000000
# (rating, 1004)     1.000000
# (rating, 6114)     1.000000
#                      ...
# (rating, 16774)    0.000000
# (rating, 16524)    0.000000
# ...
