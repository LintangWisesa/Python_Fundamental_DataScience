# %% [markdown]
# # Folium
#
# Map: OpenStreetMap (OSM)

# %%
# pip install folium, default = html
# -6.1294097, 106.8332326, 15z
import folium as fo

# %%
peta = fo.Map(
    location = [-6.1294097, 106.8332326],
    tiles = 'OpenStreetMap', # 'Stamen Terrain',
    zoom_start = 14
)

fo.Marker(
    [-6.1204097, 106.8382326],
    popup = '<img width="30px" src="data:image/jpeg;base64,...">',
    tooltip = '<i>Klik sini</i>',
    icon = fo.Icon(color='pink')
).add_to(peta)

fo.Marker(
    [-6.1294080, 106.8332330],
    popup = '<img width="30px" src="data:image/jpeg;base64,...">',
    tooltip = '<i>Klik sini</i>',
    icon = fo.Icon(color='orange')
).add_to(peta)

fo.Circle(
    location = [-6.1294080, 106.8332330],
    radius = 200,
    color = 'red',
    fill = True,
    fill_color = 'orange',
    popup = 'circle area'
).add_to(peta)

peta.add_child(fo.LatLngPopup())
# peta.save('peta.html')
peta
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
